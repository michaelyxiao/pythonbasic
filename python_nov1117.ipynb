# %% [markdown]
# # <p style="text-align: center;"><font color='blue'> Python Workshop (Basic) </font> <br> <font color='maroon'> Chicago Booth </font> <br> November 11th</p>
#
# Note that this is a markdown cell that does not execute Python code. You can turn a code cell into a markdown cell by selecting "Cell > Cell Type > Markdown" from the Jupyter Notebook menu.
#
# <hr>

# %% [markdown]
# ### Note: The single most useful Jupyter Notebook shortcut is <font color='maroon'>Shift + Enter</font> -- this will execute the code or markdown in a cell. For a complete list of shortcuts, press <font color='maroon'>Ctrl/Cmd + Shift + P.</font>
#
# <hr>
#
# ### Standard Python libraries or packages are often written in lower-level languages like C, C++, and Fortran. They abstract away a lot of the complexity and allow for simple, expressive Python commands.
#
# ### <font color='blue'>Pandas</font> is the main data analysis library used in Python. <br> <font color='blue'>Numpy</font> is the main scientific computing package. <br> <font color='blue'>Matplotlib</font> allows for creation of simple plots. <br> <font color='blue'>Seaborn</font> is built on top of matplotlib and allows for more complex visualizations.
#
# <hr>

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# We will be using one of the datasets from the recent [2017 Kaggle Data Science Survey](https://www.kaggle.com/kaggle/kaggle-survey-2017). A summary of the survey: <br> <br> "For the first time, Kaggle conducted an industry-wide survey to establish a comprehensive view of the state of data science and machine learning. The survey received over 16,000 responses and we learned a ton about who is working with data, what’s happening at the cutting edge of machine learning across industries, and how new data scientists can best break into the field."

# %% [markdown]
# # Loading Data with Pandas

# %%
# This is a comment. You can add a comment by adding a <#> in front of a line.
# read_csv is a pandas function that takes a comma-separated file and converts it into a pandas dataframe
# in memory (i.e. loaded into your computer's RAM).
# A pandas dataframe is an extremely useful data structure that has a large number of built-in
# data manipulation and data analysis functions.

df = pd.read_csv('C:/Users/Michael/Desktop/multipleChoiceResponses.csv', encoding="ISO-8859-1", low_memory=False,
                thousands = ',')
schema = pd.read_csv('C:/Users/Michael/Desktop/schema.csv')

# %%
# The head function of a pandas dataframe returns the top 5 rows and some columns. Generally
# always run this first to visually check that the data was successfully loaded.

df.head()
# Out:
#                                         GenderSelect        Country   Age  \
# 0  Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                             Female  United States  30.0
# 2                                               Male         Canada  28.0
# 3                                               Male  United States  56.0
# 4                                               Male         Taiwan  38.0
#
#                                     EmploymentStatus StudentStatus  \
# 0                                 Employed full-time           NaN
# 1                 Not employed, but looking for work           NaN
# 2                 Not employed, but looking for work           NaN
# 3  Independent contractor, freelancer, or self-em...           NaN
# 4                                 Employed full-time           NaN
#
#   LearningDataScience CodeWriter CareerSwitcher  \
# 0                 NaN        Yes            NaN
# ...

# %%
# By default, head returns 5 rows and pandas a limited number of columns. We can force pandas
# to show all columns, and also specify the number of rows to return with head.

pd.set_option('display.max_columns', None)
df.head(6)
# Out:
#                                         GenderSelect        Country   Age  \
# 0  Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                             Female  United States  30.0
# 2                                               Male         Canada  28.0
# 3                                               Male  United States  56.0
# 4                                               Male         Taiwan  38.0
# 5                                               Male         Brazil  46.0
#
#                                     EmploymentStatus StudentStatus  \
# 0                                 Employed full-time           NaN
# 1                 Not employed, but looking for work           NaN
# 2                 Not employed, but looking for work           NaN
# 3  Independent contractor, freelancer, or self-em...           NaN
# 4                                 Employed full-time           NaN
# ...

# %%
# Some of the columns are difficult to interpret, so the schema file
# contains the actual question associated with each column.


schema.head(10)
# Out:
#                      Column  \
# 0              GenderSelect
# 1            GenderFreeForm
# 2                   Country
# 3                       Age
# 4          EmploymentStatus
# 5             StudentStatus
# 6       LearningDataScience
# 7  KaggleMotivationFreeForm
# 8                CodeWriter
# 9            CareerSwitcher
#
#                                             Question         Asked
# 0     Select your gender identity. - Selected Choice           All
# 1  Select your gender identity. - A different ide...           All
# 2          Select the country you currently live in.           All
# 3                                   What's your age?           All
# 4             What's your current employment status?           All
# 5  Are you currently enrolled as a student at a d...    Non-worker
# 6  Are you currently focused on learning data sci...    Non-worker
# 7    What's your motivation for being a Kaggle user?  Non-switcher
# ...

# %%
# The describe function of a dataframe summarizes all of the numerical values
# in a dataframe.

df.describe()
# Out:
#                 Age  LearningCategorySelftTaught  \
# count  16385.000000                 13109.000000
# mean      32.372841                    33.366771
# std       10.473487                    25.787181
# min        0.000000                     0.000000
# 25%       25.000000                    15.000000
# 50%       30.000000                    30.000000
# 75%       37.000000                    50.000000
# max      100.000000                   100.000000
#
#        LearningCategoryOnlineCourses  LearningCategoryWork  \
# count                   13126.000000          13111.000000
# mean                       27.375514             15.217593
# std                        26.860840             18.996778
# min                         0.000000              0.000000
# 25%                         5.000000              0.000000
# 50%                        20.000000             10.000000
# 75%                        40.000000             25.000000
# ...

# %%
# The value_counts function of a dataframe summarizes how many rows are associated
# with each unique value. We can select a specific column from a dataframe as 
# seen below.

df['Age'].value_counts()
# Out:
# 25.0     969
# 24.0     898
# 26.0     886
# 27.0     842
# 23.0     839
# 30.0     778
# 28.0     761
# 29.0     731
# 22.0     694
# 31.0     597
# 21.0     584
# 35.0     577
# 32.0     560
# 34.0     531
# 33.0     530
# 36.0     398
# 20.0     395
# 37.0     384
# 40.0     366
# 38.0     354
# 39.0     320
# 42.0     255
# 45.0     226
# 41.0     223
# 44.0     199
# 43.0     198
# 19.0     193
# 50.0     189
# 47.0     166
# 48.0     158
# 46.0     144
# 49.0     132
# 52.0     132
# 51.0     100
# 55.0      91
# 57.0      88
# 53.0      83
# 18.0      78
# 56.0      76
# 54.0      74
# 60.0      56
# 58.0      55
# 59.0      49
# 63.0      42
# 17.0      42
# 61.0      38
# 62.0      29
# 65.0      28
# 16.0      24
# 66.0      24
# 70.0      22
# 64.0      21
# 67.0      19
# 69.0      16
# 68.0      16
# 15.0      13
# 0.0       10
# 100.0     10
# 72.0       7
# 14.0       6
# 73.0       6
# 75.0       5
# 71.0       5
# 1.0        4
# 77.0       4
# 80.0       4
# ...

# %%
# We can also run describe on a single column.

df['Age'].describe()
# Out:
# count    16385.000000
# mean        32.372841
# std         10.473487
# min          0.000000
# 25%         25.000000
# 50%         30.000000
# 75%         37.000000
# max        100.000000
# Name: Age, dtype: float64

# %%
df['GenderSelect'].value_counts()
# Out:
# Male                                                 13610
# Female                                                2778
# A different identity                                   159
# Non-binary, genderqueer, or gender non-conforming       74
# Name: GenderSelect, dtype: int64

# %%
df['GenderSelect'].describe()
# Out:
# count     16621
# unique        4
# top        Male
# freq      13610
# Name: GenderSelect, dtype: object

# %%
# One of the first things we want to check is the number of nulls in a dataset.
# The isnull() function of a dataframe returns a True/False value indicating whether
# a value is null or not.

df.isnull()
# Out:
#       GenderSelect Country    Age EmploymentStatus StudentStatus  \
# 0            False    True   True            False          True
# 1            False   False  False            False          True
# 2            False   False  False            False          True
# 3            False   False  False            False          True
# 4            False   False  False            False          True
# 5            False   False  False            False          True
# 6            False   False  False            False          True
# 7            False   False  False            False          True
# 8            False   False  False            False          True
# 9            False   False  False            False          True
# 10           False   False  False            False         False
# 11           False   False  False            False          True
# 12           False   False  False            False          True
# ...

# %%
# A dataframe is useful, but we really want to know how many nulls there are
# for each column. This will help us decide what columns to drop.

df.isnull().sum()
# Out:
# GenderSelect                                  95
# Country                                      121
# Age                                          331
# EmploymentStatus                               0
# StudentStatus                              15436
# LearningDataScience                        15432
# CodeWriter                                  3530
# CareerSwitcher                             13704
# CurrentJobTitleSelect                       4886
# TitleFit                                    5212
# CurrentEmployerType                         5115
# MLToolNextYearSelect                        5718
# MLMethodNextYearSelect                      5883
# LanguageRecommendationSelect                5718
# PublicDatasetsSelect                        5920
# LearningPlatformSelect                      5445
# LearningPlatformUsefulnessArxiv            14325
# LearningPlatformUsefulnessBlogs            11951
# LearningPlatformUsefulnessCollege          13357
# ...

# %%
# The returned list above is cutoff -- so we can force pandas to display all rows.

pd.set_option('display.max_rows', None)
df.isnull().sum()
# Out:
# GenderSelect                                      95
# Country                                          121
# Age                                              331
# EmploymentStatus                                   0
# StudentStatus                                  15436
# LearningDataScience                            15432
# CodeWriter                                      3530
# CareerSwitcher                                 13704
# CurrentJobTitleSelect                           4886
# TitleFit                                        5212
# CurrentEmployerType                             5115
# MLToolNextYearSelect                            5718
# MLMethodNextYearSelect                          5883
# LanguageRecommendationSelect                    5718
# PublicDatasetsSelect                            5920
# LearningPlatformSelect                          5445
# LearningPlatformUsefulnessArxiv                14325
# LearningPlatformUsefulnessBlogs                11951
# ...

# %%
# Lists in Python are captured in brackets: [1, 2, 3]. To create a new dataframe
# with a subset of columns of another dataframe, we can specify it in the manner
# below.

df_small = df[['Age', 'Country', 'EmploymentStatus']]
df_small.head()
# Out:
#     Age        Country                                   EmploymentStatus
# 0   NaN            NaN                                 Employed full-time
# 1  30.0  United States                 Not employed, but looking for work
# 2  28.0         Canada                 Not employed, but looking for work
# 3  56.0  United States  Independent contractor, freelancer, or self-em...
# 4  38.0         Taiwan                                 Employed full-time

# %%
# Since there are a lot of questions that went unanswered with a high volume
# of nulls, we're going to want to drop many of them. I arbitrarily selected
# a value of 25% answered as the cut-off.
#
# The dropna function drops null columns from a dataframe. axis = 1 specifies
# column (axis = 0 specifies index, not row), and the len function returns
# the length of any datatype in Python (in this case it returns the number of
# rows in the dataframe df).

df_new = df.dropna(axis = 1, thresh = len(df) * .25)
df_new.head()
# Out:
#                                         GenderSelect        Country   Age  \
# 0  Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                             Female  United States  30.0
# 2                                               Male         Canada  28.0
# 3                                               Male  United States  56.0
# 4                                               Male         Taiwan  38.0
#
#                                     EmploymentStatus CodeWriter  \
# 0                                 Employed full-time        Yes
# 1                 Not employed, but looking for work        NaN
# 2                 Not employed, but looking for work        NaN
# 3  Independent contractor, freelancer, or self-em...        Yes
# 4                                 Employed full-time        Yes
#
#               CurrentJobTitleSelect TitleFit  \
# 0             DBA/Database Engineer     Fine
# ...

# %%
# The value_counts function also has a nlargest function that returns
# the n largest values.

df_new['Country'].value_counts().nlargest(10)
# Out:
# United States                  4197
# India                          2704
# Other                          1023
# Russia                          578
# United Kingdom                  535
# People 's Republic of China     471
# Brazil                          465
# Germany                         460
# France                          442
# Canada                          440
# Name: Country, dtype: int64

# %%
# For a bar chart, you need to specify how many unique x values there are.
# The numpy arange function returns a list from 0 to 9 (if 10 is the parameter)
x = np.arange(10)

# clf clears the matplotlib figure -- otherwise you'll end up stacking plots
# one on top of the other.
plt.clf()
# Sets the figure size -- note the numbers are in inches.
plt.figure(figsize=(30,15))
# Creates a bar chart with x values, and the heights are equal to the number
# of respondents form each of the top 10 countries.
plt.bar(x, df_new['Country'].value_counts().nlargest(10).values)
# The index function returns the actual names associated with the top 10 
# countries.
plt.xticks(x, df_new['Country'].value_counts().nlargest(10).index, rotation = 45)

plt.title("Survey Respondents by Country", fontsize = 30)
plt.xlabel("Country", fontsize = 24)
plt.ylabel("Number of Respondents", fontsize = 24)

plt.grid(False)

# This sets the x/y label font sizes to be larger. Note that this is global
# and will apply to all future plots.
matplotlib.rc('xtick', labelsize=24) 
matplotlib.rc('ytick', labelsize=24) 

plt.show()

# %%
# How about a horizontal bar chart? Just flip everything around and use barh
# instead of bar

y = np.arange(10)

plt.clf()
plt.figure(figsize=(30,15))
plt.barh(y, df_new['Country'].value_counts().nlargest(10).values)
plt.yticks(y, df_new['Country'].value_counts().nlargest(10).index, rotation = 45)

plt.title("Survey Respondents by Country", fontsize = 30)
plt.ylabel("Country", fontsize = 24)
plt.xlabel("Number of Respondents", fontsize = 24)

plt.grid(False)

plt.show()

# %%
# We only care about the US...
# Also people who actually code for their job.

df_final = df_new[(df_new.Country == 'United States') &
                 (df_new.Age > 21) &
                 (df_new.Age <= 65) &
                 (df_new.CodeWriter == 'Yes')]
len(df_final)
# Out:
# 2644

# %%
# Have to clean up the compensation column to remove commas.
#
# Note the warning is due to chained assignment, which can create confusion around what value
# actually gets assigned when there are multiple steps, but we can ignore for now.

df_final['CompensationAmount'] = df_final['CompensationAmount'].astype(str).str.replace(',','')
df_final = df_final[(df_final['CompensationAmount'] != 'nan')]
df_final['CompensationAmount'] = df_final['CompensationAmount'].astype(float)
df_final = df_final[(df_final['CompensationAmount'] > 10000) &
                                        (df_final['CompensationAmount'] < 1000000)]

# %%
df_final['CompensationAmount']
# Out:
# 3        250000.0
# 15       120000.0
# 21        20000.0
# 22       100000.0
# 34       133000.0
# 75       215000.0
# 80        61000.0
# 86        83500.0
# 89       115000.0
# 100       80000.0
# 106      135000.0
# 110       75000.0
# 133       45000.0
# 146       80000.0
# 163       85000.0
# 166       65000.0
# 175      130000.0
# 178       55000.0
# 187       92000.0
# 194       79000.0
# 197      305000.0
# 203       90000.0
# 237      140000.0
# 242      160000.0
# 243       25000.0
# 247       52000.0
# 258       80000.0
# 265      120000.0
# 279       85000.0
# 283      180000.0
# 307       80000.0
# 318      180000.0
# 325      155000.0
# 328      170075.0
# 335      110000.0
# 348       30000.0
# 366       87000.0
# 370       49000.0
# 380       65000.0
# 396      180000.0
# 400      115000.0
# 402      135000.0
# 407       92000.0
# 411       40000.0
# 413      135000.0
# 418       50000.0
# 419      470000.0
# 425       12000.0
# 434      173000.0
# 445      150000.0
# ...

# %%
import matplotlib.patches as mpatches

# Let's make a histogram of compensation

plt.clf()
plt.figure(figsize=(30,15))
plt.hist(df_final['CompensationAmount'], rwidth = .9, bins = 40)

# We can draw lines directly on the plot -- here we draw the median in red and
# mean in green
plt.axvline(df_final['CompensationAmount'].median(), color='r', linestyle='dashed', linewidth=2)
plt.axvline(df_final['CompensationAmount'].mean(), color='g', linestyle='dashed', linewidth=2)

plt.title("Compensation (Salary + Bonus)", fontsize = 30)
plt.ylabel("Respondents", fontsize = 24)
plt.xlabel("Compensation", fontsize = 24)
plt.xticks([50000, 100000, 150000, 200000, 250000, 300000, 350000, 400000, 450000, 500000, 550000])

# Add a legend
plt.rcParams["legend.fontsize"] = 30
red_patch = mpatches.Patch(color='red', label='Median')
green_patch = mpatches.Patch(color='green', label='Average')
plt.legend(handles=[red_patch, green_patch])

plt.show()

# %%
# Let's do a line chart

plt.clf()
plt.figure(figsize=(30,15))
plt.plot(df_final['CompensationAmount'].groupby(df_final['Age']).mean().index, 
         df_final['CompensationAmount'].groupby(df_final['Age']).mean(),
        linewidth = 10)
plt.yticks([50000, 75000, 100000, 125000, 150000, 175000, 200000])

plt.title("Average Compensation by Age", fontsize = 30)
plt.ylabel("Salary", fontsize = 24)
plt.xlabel("Age", fontsize = 24)

plt.grid(False)

plt.show()

# %%
# Seaborn (sns) is built on top of matplotlib and providers
# more colorful visualizations
#
# Violin chart

plt.clf()
plt.figure(figsize=(30,15))
sns.violinplot(y='CompensationAmount', x='FormalEducation', data=df_final, bw = .5, legend = True)
plt.title("Salary distribution for US data scientists", fontsize=24)
plt.ylabel("Annual Salary", fontsize=24)
plt.xlabel("Education Level", fontsize=24)
plt.show()

# %%
# Colorful bar chart
plt.clf()
plt.figure(figsize=(30,15))
sns.countplot(y=df_final['MajorSelect'])
plt.title("College Majors", fontsize=30)
plt.xlabel("Number of respondents", fontsize=24)
plt.ylabel("Major", fontsize=24)
plt.show()
